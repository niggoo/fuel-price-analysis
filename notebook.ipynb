# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data_dir="fuel-prices.csv"

# %% [markdown]
# # Data Check

# %%
data = pd.read_csv(data_dir, names=["Date", "Name", "Price"], sep=";")
display(data)
display(data.info())
# Out:
#                            Date                                      Name  \
# 0     2022-06-18T14:40:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1     2022-06-18T15:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 2     2022-06-18T16:00:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 3     2022-06-18T17:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 4     2022-06-18T18:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# ...                         ...                                       ...
# 1968  2022-09-08T14:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1969  2022-09-08T15:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1970  2022-09-08T16:30:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1971  2022-09-08T17:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1972  2022-09-08T18:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
#
#       Price
# 0     2.034
# 1     2.034
# 2     2.034
# 3     2.034
# 4     2.034
# ...     ...
# 1968  1.919
# 1969  1.919
# 1970  1.919
# 1971  1.919
# 1972  1.919
#
# [1973 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1973 entries, 0 to 1972
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1973 non-null   object
#  1   Name    1972 non-null   object
#  2   Price   1970 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 46.4+ KB
# None

# %%
data["Date"] = pd.to_datetime(data["Date"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1973 entries, 0 to 1972
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1973 non-null   datetime64[ns, pytz.FixedOffset(120)]
#  1   Name    1972 non-null   object
#  2   Price   1970 non-null   float64
# dtypes: datetime64[ns, pytz.FixedOffset(120)](1), float64(1), object(1)
# memory usage: 46.4+ KB

# %%
data[data.isnull().any(axis=1)]
# Out:
#                          Date                                       Name  \
# 22  2022-06-19 12:00:01+02:00  OMV - Engerwitzdorf Freistädter Straße 50
# 46  2022-06-20 12:00:02+02:00  OMV - Engerwitzdorf Freistädter Straße 50
# 914 2022-07-26 16:30:18+02:00                                        NaN
#
#      Price
# 22     NaN
# 46     NaN
# 914    NaN

# %% [markdown]
# # Drop faulty rows

# %%
data.drop([22, 46, 914], inplace=True, axis="index")

# %%
data.isnull().sum()
# Out:
# Date     0
# Name     0
# Price    0
# dtype: int64

# %% [markdown]
# # Extract more information out of "Date" column

# %%
data["Day Of Week"] = data["Date"].dt.day_name()
data["Month"] = data["Date"].dt.month_name()
data["Week Of Year"] = data["Date"].dt.isocalendar().week
data["Day Of Year"] = data["Date"].dt.dayofyear
data["Year"] = data["Date"].dt.year
data
# Out:
#                           Date                                      Name  \
# 0    2022-06-18 14:40:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1    2022-06-18 15:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 2    2022-06-18 16:00:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 3    2022-06-18 17:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 4    2022-06-18 18:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# ...                        ...                                       ...
# 1968 2022-09-08 14:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1969 2022-09-08 15:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1970 2022-09-08 16:30:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1971 2022-09-08 17:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1972 2022-09-08 18:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
#
#       Price Day Of Week      Month  Week Of Year  Day Of Year  Year
# 0     2.034    Saturday       June            24          169  2022
# 1     2.034    Saturday       June            24          169  2022
# 2     2.034    Saturday       June            24          169  2022
# 3     2.034    Saturday       June            24          169  2022
# 4     2.034    Saturday       June            24          169  2022
# ...     ...         ...        ...           ...          ...   ...
# 1968  1.919    Thursday  September            36          251  2022
# 1969  1.919    Thursday  September            36          251  2022
# 1970  1.919    Thursday  September            36          251  2022
# 1971  1.919    Thursday  September            36          251  2022
# 1972  1.919    Thursday  September            36          251  2022
#
# [1970 rows x 8 columns]

# %% [markdown]
# # Overall plot

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=data, x="Date", y="Price", hue="Name")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=data, x="Date", y="Price", hue="Month")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Price'>

# %%
fig, axs = plt.subplots(2,2,figsize=(20,8))
months = [ 
    ((0,0), "June"), 
    ((0,1), "July"), 
    ((1,0), "August"), 
    ((1,1), "September")
]

for pos, month in months:
    sns.lineplot(data=data[data["Month"] == month], x="Date", y="Price", hue="Month", ax=axs[pos])

# %% [markdown]
# # Min price for each day

# %%
min_price_day_of_year = data.loc[data.groupby(["Day Of Year"]).Price.idxmin()]
min_price_day_of_year
# Out:
#                           Date                                      Name  \
# 0    2022-06-18 14:40:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 23   2022-06-19 13:00:02+02:00                        Diskont Tankstelle
# 34   2022-06-20 00:00:02+02:00                 PINK - so pink, so clever
# 68   2022-06-21 10:30:02+02:00                       AVIA XPress TS Raml
# 82   2022-06-22 00:30:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# ...                        ...                                       ...
# 1880 2022-09-04 22:30:01+02:00      speed-DISKONT-automatic Steyregg/Ort
# 1892 2022-09-05 10:30:02+02:00                       AVIA XPress TS Raml
# 1917 2022-09-06 11:30:01+02:00                       AVIA XPress TS Raml
# 1941 2022-09-07 11:30:01+02:00                       AVIA XPress TS Raml
# 1964 2022-09-08 10:30:02+02:00                       AVIA XPress TS Raml
#
#       Price Day Of Week      Month  Week Of Year  Day Of Year  Year
# 0     2.034    Saturday       June            24          169  2022
# 23    2.014      Sunday       June            24          170  2022
# 34    2.009      Monday       June            25          171  2022
# 68    2.029     Tuesday       June            25          172  2022
# 82    2.044   Wednesday       June            25          173  2022
# ...     ...         ...        ...           ...          ...   ...
# 1880  1.874      Sunday  September            35          247  2022
# 1892  1.872      Monday  September            36          248  2022
# 1917  1.871     Tuesday  September            36          249  2022
# 1941  1.893   Wednesday  September            36          250  2022
# 1964  1.915    Thursday  September            36          251  2022
#
# [83 rows x 8 columns]

# %% [markdown]
# # Max price for each day

# %%
max_price_day_of_year = data.loc[data.groupby(["Day Of Year"]).Price.idxmax()]
max_price_day_of_year
# Out:
#                           Date                                      Name  \
# 0    2022-06-18 14:40:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 17   2022-06-19 07:00:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 47   2022-06-20 13:00:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 70   2022-06-21 12:30:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 82   2022-06-22 00:30:02+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# ...                        ...                                       ...
# 1858 2022-09-04 00:30:01+02:00      speed-DISKONT-automatic Steyregg/Ort
# 1894 2022-09-05 12:30:01+02:00                       AVIA XPress TS Raml
# 1918 2022-09-06 12:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1942 2022-09-07 12:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
# 1954 2022-09-08 00:30:01+02:00  Genol Lagerhaus Pregarten-Gallneukirchen
#
#       Price Day Of Week      Month  Week Of Year  Day Of Year  Year
# 0     2.034    Saturday       June            24          169  2022
# 17    2.034      Sunday       June            24          170  2022
# 47    2.034      Monday       June            25          171  2022
# 70    2.044     Tuesday       June            25          172  2022
# 82    2.044   Wednesday       June            25          173  2022
# ...     ...         ...        ...           ...          ...   ...
# 1858  1.888      Sunday  September            35          247  2022
# 1894  1.909      Monday  September            36          248  2022
# 1918  1.919     Tuesday  September            36          249  2022
# 1942  1.919   Wednesday  September            36          250  2022
# 1954  1.919    Thursday  September            36          251  2022
#
# [83 rows x 8 columns]

# %% [markdown]
# # Price each incl. margin

# %%
plt.figure(figsize=(20,8))
sns.lineplot(data=data, x="Day Of Year", y="Price", hue="Month")
# Out:
# <AxesSubplot:xlabel='Day Of Year', ylabel='Price'>

# %% [markdown]
# # Min price per week

# %%
min_price_week_of_year = data.loc[data.groupby(["Week Of Year"]).Price.idxmin()]
min_price_week_of_year
# Out:
#                           Date                                  Name  Price  \
# 23   2022-06-19 13:00:02+02:00                    Diskont Tankstelle  2.014
# 34   2022-06-20 00:00:02+02:00             PINK - so pink, so clever  2.009
# 213  2022-06-27 11:30:01+02:00                   AVIA XPress TS Raml  2.017
# 426  2022-07-06 08:30:01+02:00                   AVIA XPress TS Raml  2.022
# 702  2022-07-17 20:30:02+02:00                   AVIA XPress TS Raml  2.001
# 839  2022-07-23 13:30:02+02:00                   AVIA XPress TS Raml  1.974
# 1027 2022-07-31 09:30:01+02:00                   AVIA XPress TS Raml  1.914
# 1149 2022-08-05 11:30:01+02:00                   AVIA XPress TS Raml  1.834
# 1345 2022-08-13 15:30:01+02:00                   AVIA XPress TS Raml  1.734
# 1413 2022-08-16 11:30:01+02:00                   AVIA XPress TS Raml  1.722
# 1557 2022-08-22 11:30:02+02:00                   AVIA XPress TS Raml  1.723
# 1714 2022-08-29 00:30:02+02:00  speed-DISKONT-automatic Steyregg/Ort  1.810
# 1917 2022-09-06 11:30:01+02:00                   AVIA XPress TS Raml  1.871
#
#      Day Of Week      Month  Week Of Year  Day Of Year  Year
# 23        Sunday       June            24          170  2022
# 34        Monday       June            25          171  2022
# 213       Monday       June            26          178  2022
# 426    Wednesday       July            27          187  2022
# 702       Sunday       July            28          198  2022
# 839     Saturday       July            29          204  2022
# 1027      Sunday       July            30          212  2022
# 1149      Friday     August            31          217  2022
# 1345    Saturday     August            32          225  2022
# 1413     Tuesday     August            33          228  2022
# 1557      Monday     August            34          234  2022
# 1714      Monday     August            35          241  2022
# 1917     Tuesday  September            36          249  2022

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=min_price_week_of_year, x="Week Of Year", y="Price", hue="Day Of Week")
# Out:
# <AxesSubplot:xlabel='Week Of Year', ylabel='Price'>

# %%
min_price_week_of_year.groupby(["Day Of Week"])["Price"].count().sort_values().reset_index(name='Counts')
# Out:
#   Day Of Week  Counts
# 0      Friday       1
# 1   Wednesday       1
# 2    Saturday       2
# 3     Tuesday       2
# 4      Sunday       3
# 5      Monday       4

# %%
mean_price_day_of_week = data.groupby(["Day Of Week"]).mean()["Price"].to_frame().reindex([ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']) 
mean_price_day_of_week
# Out:
#                 Price
# Day Of Week
# Monday       1.922627
# Tuesday      1.927561
# Wednesday    1.927069
# Thursday     1.928049
# Friday       1.932402
# Saturday     1.930040
# Sunday       1.925185

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=mean_price_day_of_week, x="Day Of Week", y="Price")
# Out:
# <AxesSubplot:xlabel='Day Of Week', ylabel='Price'>
